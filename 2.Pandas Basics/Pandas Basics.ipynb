# %%
import pandas as pd

# %% [markdown]
# # Creating a Series

# %%
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([10,20,30],index=['a','b','c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print(s['a'])
print(s[0])
# Out:
# 10
# 10

# %% [markdown]
# # Creating the DataFrame

# %%
data = {
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'Salary':[50000,60000,70000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
print(df.shape)
print(df.columns)
print(df.index)
print(df.dtypes)
# Out:
# (3, 3)
# Index(['Name', 'Age', 'Salary'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)
# Name      object
# Age        int64
# Salary     int64
# dtype: object

# %% [markdown]
# # Selecting Columns

# %%
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
print(df[['Name','Salary']])
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   70000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes
# None

# %%
print(df.describe())
# Out:
#         Age   Salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0

# %%
print(df['Salary'].value_counts())
# Out:
# 50000    1
# 60000    1
# 70000    1
# Name: Salary, dtype: int64

# %%
print(df['Salary'].unique)
# Out:
# <bound method Series.unique of 0    50000
# 1    60000
# 2    70000
# Name: Salary, dtype: int64>

# %%
print(df['Salary'].nunique())
# Out:
# 3

# %% [markdown]
# # Indexing and Selection

# %%
print(df.loc[0])
# Out:
# Name      Alice
# Age          25
# Salary    50000
# Name: 0, dtype: object

# %%
print(df.loc[0,'Name'])
# Out:
# Alice

# %%
df.loc[0:2]
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
df.set_index('Name',inplace=True)
print(df)
# Out:
#          Age  Salary
# Name
# Alice     25   50000
# Bob       30   60000
# Charlie   35   70000

# %%
print(df.loc['Alice'])
# Out:
# Age          25
# Salary    50000
# Name: Alice, dtype: int64

# %%
print(df.iloc[0])
# Out:
# Age          25
# Salary    50000
# Name: Alice, dtype: int64

# %%
print(df.iloc[0,1])
# Out:
# 50000

# %% [markdown]
# # Data Filtering

# %%
print(df[df['Age']>=30])
# Out:
#          Age  Salary
# Name
# Bob       30   60000
# Charlie   35   70000

# %%
iris = pd.read_csv("iris.csv")
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = iris.copy()
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.head(6)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (150, 5)
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# if we want to change the name of the columns then 
df.columns = [] # here we neeed to pass the same number of list size

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(df["sepal.length"])
# we can also access the column using df.sepallength
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
df.isnull()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()  # it sums how much entries are null in particular column
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.iloc[1:4,2:4]
# Out:
#    petal.length  petal.width
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
a = df.drop(0) # it removes the 0th row and create the new copy of it if we does not provide inplace=True
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.drop(0,inplace=True) # it removes the oth row and it removes using lebel and not index
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
df.index
# Out:
# RangeIndex(start=1, stop=150, step=1)

# %%
df.index[0],df.index[3]
# Out:
# (1, 4)

# %%
df.drop(df.index[[0,1]],inplace = True)  # to remove the multiple rows using index
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
df["sepal.length"]>5
# Out:
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: sepal.length, Length: 147, dtype: bool

# %%
df[df["sepal.length"]>5]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 5             5.4          3.9           1.7          0.4     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 14            5.8          4.0           1.2          0.2     Setosa
# 15            5.7          4.4           1.5          0.4     Setosa
# 16            5.4          3.9           1.3          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [117 rows x 5 columns]

# %%
df[df.variety == 'Setosa'].describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count     47.000000    47.000000     47.000000    47.000000
# mean       5.012766     3.440426      1.468085     0.248936
# std        0.360324     0.384289      0.177061     0.108091
# min        4.300000     2.300000      1.000000     0.100000
# 25%        4.800000     3.200000      1.400000     0.200000
# 50%        5.000000     3.400000      1.500000     0.200000
# 75%        5.200000     3.700000      1.600000     0.300000
# max        5.800000     4.400000      1.900000     0.600000

# %%
df.reset_index(drop = True,inplace = True) 
df.index
# Out:
# RangeIndex(start=0, stop=147, step=1)

# %%
del df["sepal.width"]   #to delete the column

# %%
df
# Out:
#      sepal.length  petal.length  petal.width    variety
# 0             4.6           1.5          0.2     Setosa
# 1             5.0           1.4          0.2     Setosa
# 2             5.4           1.7          0.4     Setosa
# 3             4.6           1.4          0.3     Setosa
# 4             5.0           1.5          0.2     Setosa
# ..            ...           ...          ...        ...
# 142           6.7           5.2          2.3  Virginica
# 143           6.3           5.0          1.9  Virginica
# 144           6.5           5.2          2.0  Virginica
# 145           6.2           5.4          2.3  Virginica
# 146           5.9           5.1          1.8  Virginica
#
# [147 rows x 4 columns]

# %%
df = iris.copy()
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df["difference_pl_pw"] = df["petal.length"] -df["petal.width"]  #to add the new column
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      difference_pl_pw
# 0                 1.2
# 1                 1.2
# 2                 1.1
# 3                 1.3
# ...

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  \
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#
#    difference_pl_pw
# 0               1.2
# 1               1.2
# 2               1.1
# 3               1.3
# 4               1.2

# %%
df.iloc[2:4,1:3] = 0
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  \
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          0.0           0.0          0.2  Setosa
# 3           4.6          0.0           0.0          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#
#    difference_pl_pw
# 0               1.2
# 1               1.2
# 2               1.1
# 3               1.3
# 4               1.2

# %%
import numpy as np

# %%
df.iloc[2:4,1:3] = np.nan
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          NaN           NaN          0.2     Setosa
# 3             4.6          NaN           NaN          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      difference_pl_pw
# 0                 1.2
# 1                 1.2
# 2                 1.1
# 3                 1.3
# ...

# %%
df.dropna(inplace = True)  # to remove the na entries and if we want to make changes inplace

# %%
df.head()
df.reset_index(drop = True,inplace = True)
df.head
# Out:
# <bound method NDFrame.head of      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             5.0          3.6           1.4          0.2     Setosa
# 3             5.4          3.9           1.7          0.4     Setosa
# 4             4.6          3.4           1.4          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7          3.0           5.2          2.3  Virginica
# 144           6.3          2.5           5.0          1.9  Virginica
# 145           6.5          3.0           5.2          2.0  Virginica
# 146           6.2          3.4           5.4          2.3  Virginica
# 147           5.9          3.0           5.1          1.8  Virginica
#
#      difference_pl_pw
# 0                 1.2
# 1                 1.2
# 2                 1.2
# ...

# %%
df.iloc[2:4,1:3] = np.nan
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             5.0          NaN           NaN          0.2     Setosa
# 3             5.4          NaN           NaN          0.4     Setosa
# 4             4.6          3.4           1.4          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7          3.0           5.2          2.3  Virginica
# 144           6.3          2.5           5.0          1.9  Virginica
# 145           6.5          3.0           5.2          2.0  Virginica
# 146           6.2          3.4           5.4          2.3  Virginica
# 147           5.9          3.0           5.1          1.8  Virginica
#
#      difference_pl_pw
# 0                 1.2
# 1                 1.2
# 2                 1.2
# 3                 1.3
# ...

# %%
df["sepal.width"].fillna(df["sepal.width"].mean(),inplace = True)
df["petal.length"].fillna(df["petal.length"].mean(),inplace = True)
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1     3.500000      1.400000          0.2     Setosa
# 1             4.9     3.000000      1.400000          0.2     Setosa
# 2             5.0     3.046575      3.820548          0.2     Setosa
# 3             5.4     3.046575      3.820548          0.4     Setosa
# 4             4.6     3.400000      1.400000          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7     3.000000      5.200000          2.3  Virginica
# 144           6.3     2.500000      5.000000          1.9  Virginica
# 145           6.5     3.000000      5.200000          2.0  Virginica
# 146           6.2     3.400000      5.400000          2.3  Virginica
# 147           5.9     3.000000      5.100000          1.8  Virginica
#
#      difference_pl_pw
# 0                 1.2
# 1                 1.2
# 2                 1.2
# 3                 1.3
# ...

# %%
#strings based data
df["Gender"] = "Female"
df.iloc[0:10,6] = "Male"
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1     3.500000      1.400000          0.2     Setosa
# 1             4.9     3.000000      1.400000          0.2     Setosa
# 2             5.0     3.046575      3.820548          0.2     Setosa
# 3             5.4     3.046575      3.820548          0.4     Setosa
# 4             4.6     3.400000      1.400000          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7     3.000000      5.200000          2.3  Virginica
# 144           6.3     2.500000      5.000000          1.9  Virginica
# 145           6.5     3.000000      5.200000          2.0  Virginica
# 146           6.2     3.400000      5.400000          2.3  Virginica
# 147           5.9     3.000000      5.100000          1.8  Virginica
#
#      difference_pl_pw  Gender
# 0                 1.2    Male
# 1                 1.2    Male
# 2                 1.2    Male
# ...

# %%
def f(s):
    if s == "Male":
        return 0
    else :
        return 1
    
df["sex"] = df.Gender.apply(f)
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1     3.500000      1.400000          0.2     Setosa
# 1             4.9     3.000000      1.400000          0.2     Setosa
# 2             5.0     3.046575      3.820548          0.2     Setosa
# 3             5.4     3.046575      3.820548          0.4     Setosa
# 4             4.6     3.400000      1.400000          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7     3.000000      5.200000          2.3  Virginica
# 144           6.3     2.500000      5.000000          1.9  Virginica
# 145           6.5     3.000000      5.200000          2.0  Virginica
# 146           6.2     3.400000      5.400000          2.3  Virginica
# 147           5.9     3.000000      5.100000          1.8  Virginica
#
#      difference_pl_pw  Gender  sex
# 0                 1.2    Male    0
# 1                 1.2    Male    0
# ...

# %%
del df["Gender"]
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1     3.500000      1.400000          0.2     Setosa
# 1             4.9     3.000000      1.400000          0.2     Setosa
# 2             5.0     3.046575      3.820548          0.2     Setosa
# 3             5.4     3.046575      3.820548          0.4     Setosa
# 4             4.6     3.400000      1.400000          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7     3.000000      5.200000          2.3  Virginica
# 144           6.3     2.500000      5.000000          1.9  Virginica
# 145           6.5     3.000000      5.200000          2.0  Virginica
# 146           6.2     3.400000      5.400000          2.3  Virginica
# 147           5.9     3.000000      5.100000          1.8  Virginica
#
#      difference_pl_pw  sex
# 0                 1.2    0
# 1                 1.2    0
# 2                 1.2    0
# ...

# %%
ans = df.groupby(['sepal.length'])[['sepal.width','petal.length']].mean()
print(ans)
# Out:
#               sepal.width  petal.length
# sepal.length
# 4.3              3.000000      1.100000
# 4.4              3.033333      1.333333
# 4.5              2.300000      1.300000
# 4.6              3.400000      1.266667
# 4.7              3.200000      1.600000
# 4.8              3.180000      1.580000
# 4.9              2.950000      2.266667
# 5.0              3.064658      2.082055
# 5.1              3.477778      1.722222
# 5.2              3.425000      2.075000
# 5.3              3.700000      1.500000
# 5.4              3.407763      2.386758
# 5.5              2.842857      3.228571
# 5.6              2.816667      4.200000
# 5.7              3.100000      3.587500
# 5.8              2.885714      4.071429
# 5.9              3.066667      4.700000
# 6.0              2.733333      4.650000
# 6.1              2.850000      4.750000
# 6.2              2.825000      4.750000
# 6.3              2.855556      5.133333
# 6.4              2.957143      5.157143
# ...
